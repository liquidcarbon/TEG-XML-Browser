# %% [markdown]
# # 3. TEG XML Parser
#
# > Converting XML data to JSON from factory and customer files

# %%
#| code-fold: true
from datetime import datetime; datetime.now().strftime("created: %F %H:%M")
# Out:
# 'created: 2023-04-27 11:22'

# %% [markdown]
# ## Generating insights from XML collected from different sources.
#
# TLDR: we can pull data straight from SharePoint and process many files in minutes.  Scroll to <a href="#Insights">insights</a>.
#
# In the first notebook, rationale is presented for processing XML files into JSON format.
#
# The second notebook demostrated retrieval of XML files from SharePoint.
#
# Here, we're bringing it together.

# %%
#| hide
# %load_ext autoreload
# %autoreload 2

# %%
#| default_exp io

# %%
#| hide
from fastcore.test import *
from nbdev.showdoc import *

# %%
#| export
from collections import abc
from dotenv import dotenv_values
from loguru import logger as log
from office365.runtime.auth.user_credential import UserCredential
from office365.runtime.client_request_exception import ClientRequestException
from office365.sharepoint.client_context import ClientContext as SharePointClientContext
import ast
import io
import json
import os
import re
import sys
import xmltodict

# %%
#| hide
log.remove()
log.add(sys.stdout, format="{time:YYYY-MM-DD@HH:mm:ss.SSS}|{level}|{function}|{message}")
log.debug("Logger started")
# Out:
# 2023-04-27@11:22:23.041|DEBUG|<module>|Logger started

# %%
#| exports
#| code-fold: true
class TEGXMLProcessor:
    """Pipeline for TEG6s XML processing."""

    ROOT_TAG = bytes("Cartridge", encoding="utf-8")  # assumption that this will be true

    @classmethod
    def from_local_file(
        cls,
        local_filepath: str  # path to input XML file
    ):
        """Read from a local XML file."""
        instance = cls()
        instance.local_filepath = local_filepath
        log.debug("reading from a local file...")

        try:
            with open(local_filepath, "rb") as f:
                instance.content = f.read()
            instance.raw_length = len(instance.content)
            log.info(f"Read {instance.raw_length:,d} bytes of raw XML data")
        except Exception as e:
            log.error(f"unable to read file: {e}")
        return instance

    @classmethod
    def from_sharepoint_guid(
        cls,
        ctx: SharePointClientContext,  # SharePoint connection object
        sharepoint_guid: str  # SharePoint globally unique ID
    ):
        """Read from SharePoint. Requires initialized ClientContext."""
        instance = cls()
        instance.sharepoint_guid = sharepoint_guid
        log.debug("reading from SharePoint...")

        try:
            with io.BytesIO() as bytestream:
                ctx.web.get_file_by_id(sharepoint_guid).download(bytestream).execute_query()
                instance.raw_length = bytestream.tell()
                log.info(f"read {instance.raw_length:,d} bytes from file {sharepoint_guid}")
                bytestream.seek(0)  # rewind IO buffer
                instance.content = bytestream.read()
        except Exception as e:
            log.error(f"unable to read SharePoint file: {e}")          
        return instance

    def find_xml_offsets(self):
        """Scans for XML fragments."""
        xml_open_bytes = [x.start() for x in re.finditer(b"<\?xml", self.content)]
        xml_close_bytes = [x.end() for x in re.finditer(self.ROOT_TAG+b">", self.content)]
        if len(xml_open_bytes) != len(xml_close_bytes):
            log.error("XML heads not equal XML tails")
        else:
            xml_offsets = [(start, end) for start, end in zip(xml_open_bytes, xml_close_bytes)]
            log.info(f"found {len(xml_offsets)} XML fragment(s)")
            return xml_offsets

    def parse(self):
        if self.content.startswith(b"<?xml"):
            _to_parse = self.content
        else:
            offsets = self.find_xml_offsets()
            start, end  = offsets[-1]  # this is an ASSUMPTION
            _to_parse = self.content[start:end]
        try:
            self.d = xmltodict.parse(
                _to_parse,
                attr_prefix="",
                postprocessor=xml_unstringify,
            )
            self.id = self.d["Cartridge"]["CartridgeResult"]["TestResultID"]
            log.info("XML parsed")
        except Exception as e:
            log.error(f"Nope: {e}")

    def pop_lists(self):
        """Recursively iterate through dictionary and pop all lists into a separate object."""
        self.lists = {}
        def walk_and_pop(nested_dict, path=tuple()):
            for key, value in nested_dict.copy().items():
                nested_path = path + (key,)
                if isinstance(value, list):  # is it a list? pop it
                    self.lists[nested_path] = nested_dict.pop(key)
                elif isinstance(value, abc.Mapping):  # https://stackoverflow.com/a/35691011/9511034
                    walk_and_pop(value, path=nested_path)  # is it a dict? go deeper
                else:
                    continue
        walk_and_pop(self.d)
        return

    def save_jsons(self):
        """Saves parsed XML data in JSON files."""
        metadata_filepath = self.filepath.rstrip(".xml") + "_metadata.json"
        self.save_metadata_json(output_filepath=metadata_filepath)
        
    def save_metadata_json(
        self,
        output_filepath: str  # path to output file
    ):
        """Saves metadata as a JSON file."""
        _output = json.dumps(self.d, indent=4)
        with open(output_filepath, "w") as f:
            f.write(_output)
        log.info(f"wrote {len(_output):,d} bytes to {output_filepath}")


def unstringify(value):
    """Converts stringified numbers to integers or floats."""
    try:
        value = ast.literal_eval(val)
    except:
        pass
    return value


def xml_unstringify(path, key, value):
    """Used as a callable for `xmldict.parse`.
    
    Casts numbers that appears as strings in XML back to integers or floats.
    """
    if value == "true":
        value = "True"
    if value == "false":
        value = "False"
    return key, unstringify(value)

# %% [markdown]
# ## Factory Files

# %%
base_folder = "../../hae/random_factory_XML_48001_53286/"
xml_file = os.path.join(base_folder, os.listdir(base_folder)[0])
tegxml = TEGXMLProcessor.from_local_file(xml_file)
tegxml.parse()
print(tegxml.d['Cartridge'].keys())
# Out:
# 2023-04-27@11:22:23.118|DEBUG|from_local_file|reading from a local file...
# 2023-04-27@11:22:23.127|INFO|from_local_file|Read 788,588 bytes of raw XML data
# 2023-04-27@11:22:23.324|INFO|parse|XML parsed
# dict_keys(['xmlns:xsi', 'xmlns:xsd', 'SchemaVersion', 'AllowTemperatureChange', 'BarcodeExpirationDate', 'CalculatedExpirationDate', 'CartridgeName', 'SampleType', 'TestType', 'DisplayTemplate', 'MicrofluidicsScriptName', 'MicrofluidicsScriptVersion', 'IsDiagnostics', 'ExecutedTest', 'CartridgeID', 'CartridgeRevision', 'ManufacturingData', 'CartridgeTests', 'ExtraCalculations', 'CartridgeResult'])

# %% [markdown]
# ## Customer Files

# %%
base_folder = "../../hae/T1-19B-Cartridges/"
xml_file = [f for f in os.listdir(base_folder) if f.endswith(".xml")][0]
xml_file = os.path.join(base_folder, xml_file)

tegxml = TEGXMLProcessor.from_local_file(xml_file)
tegxml.parse()
print(tegxml.d['Cartridge'].keys())
# Out:
# 2023-04-27@11:22:23.366|DEBUG|from_local_file|reading from a local file...
# 2023-04-27@11:22:23.372|INFO|from_local_file|Read 219,361 bytes of raw XML data
# 2023-04-27@11:22:23.376|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:22:23.427|INFO|parse|XML parsed
# dict_keys(['xmlns:xsi', 'xmlns:xsd', 'SchemaVersion', 'AllowTemperatureChange', 'BarcodeExpirationDate', 'CalculatedExpirationDate', 'CartridgeName', 'SampleType', 'TestType', 'DisplayTemplate', 'MicrofluidicsScriptName', 'MicrofluidicsScriptVersion', 'IsDiagnostics', 'ExecutedTest', 'CartridgeID', 'CartridgeRevision', 'ManufacturingData', 'CartridgeTests', 'ExtraCalculations', 'CartridgeResult'])

# %% [markdown]
# ## SharePoint Files

# %%
#| export
config = dotenv_values("../.env")
sharepoint_url = config["SHAREPOINT_URL"]
credentials = UserCredential(config["USERNAME"], config["PASSWORD"])
ctx = SharePointClientContext(sharepoint_url).with_credentials(credentials)

# %%
sharepoint_guid = "66e6a98a-3308-4a83-bc38-00818e953985"
tegxml = TEGXMLProcessor.from_sharepoint_guid(ctx, sharepoint_guid)
tegxml.parse()
print(tegxml.d['Cartridge'].keys())
# Out:
# 2023-04-27@11:22:23.494|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:22:25.544|INFO|from_sharepoint_guid|read 1,342,694 bytes from file 66e6a98a-3308-4a83-bc38-00818e953985
# 2023-04-27@11:22:25.547|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:22:25.879|INFO|parse|XML parsed
# dict_keys(['xmlns:xsi', 'xmlns:xsd', 'SchemaVersion', 'AllowTemperatureChange', 'BarcodeExpirationDate', 'CalculatedExpirationDate', 'CartridgeName', 'SampleType', 'TestType', 'DisplayTemplate', 'MicrofluidicsScriptName', 'MicrofluidicsScriptVersion', 'IsDiagnostics', 'ExecutedTest', 'CartridgeID', 'CartridgeRevision', 'ManufacturingData', 'CartridgeTests', 'ExtraCalculations', 'CartridgeResult'])

# %% [markdown]
# ### What are the two fragments?
#
# There are two large XML fragments of similar structure. All sections except `CartridgeResult` appear to be identical. In `CartridgeResult`, the first section and the second section are the same, except the second section has one extra key `'SRs'`, which contains the experimental results.
#
# Assuming this is the case for every file (**to be verified**), we will always use the second section.

# %%
xml_offsets = tegxml.find_xml_offsets()
xml_offsets
# Out:
# 2023-04-27@11:22:25.906|INFO|find_xml_offsets|found 2 XML fragment(s)
# [(120, 10673), (10692, 1340947)]

# %%
d = {}
for i, (x,y) in enumerate(xml_offsets):
    d[i] = xmltodict.parse(
        tegxml.content[x:y],
        attr_prefix="",
    )['Cartridge']

# %%
for k in d[0].keys():
    print(d[0][k] == d[1][k], k)
# Out:
# True xmlns:xsi
# True xmlns:xsd
# True SchemaVersion
# True AllowTemperatureChange
# True BarcodeExpirationDate
# True CalculatedExpirationDate
# True CartridgeName
# True SampleType
# True TestType
# True DisplayTemplate
# True MicrofluidicsScriptName
# True MicrofluidicsScriptVersion
# True IsDiagnostics
# True ExecutedTest
# True CartridgeID
# True CartridgeRevision
# True ManufacturingData
# True CartridgeTests
# True ExtraCalculations
# False CartridgeResult

# %%
for k in d[0]['CartridgeResult'].keys():
    print(d[0]['CartridgeResult'][k] == d[1]['CartridgeResult'][k], k)
# Out:
# True TestResultID
# True CompletionTime
# True TestStartTime
# True Status
# True ErrorReason
# True ResultFlags
# True TestDurationSec
# True PatientID
# True UserName
# True L1LastQCTestResultID
# True L2LastQCTestResultID
# True LastCalibrationID
# True L1WetQCStatus
# True L2WetQCStatus
# True PPIDRequestResult
# True InstrumentDetails
# True TestInformation
# False MicrofluidicsLog
# False CartridgeResultEventLog
# False InstrumentMonitoring
# False ChannelResults

# %%
for k in d[0]['CartridgeResult']['ChannelResults']['ChannelResult'][0].keys():
    print(d[0]['CartridgeResult']['ChannelResults']['ChannelResult'][0][k] == \
          d[1]['CartridgeResult']['ChannelResults']['ChannelResult'][0][k], k)
# Out:
# True CN
# True CST
# True CalculationParameterType
# True Stat
# True TempC
# True LowSetpointMaximumTemperature
# True Flags
# True CPs
# True MA
# False SRs
# True ExtraChannelCalculationResults

# %% [markdown]
# ## Extracting useful data

# %% [markdown]
# ### Processing a SharePoint Folder
# 400 SharePoint files in 6 minutes

# %%
#| exports
#| code-fold: true
def get_sharepoint_ids(
    parent_folder_url: str,  # SharePoint URL (TODO: %20 URL formatting)
    ctx: SharePointClientContext,  # SharePoint connection object
):
    """Recursively traverse files and folders and retrieve SharePoint GUIDs."""

    sharepoint_folder = ctx.web.get_folder_by_server_relative_url(parent_folder_url).get().execute_query()

    def traverse_sharepoint_folder(parent_folder, file_dict):
        parent_folder.expand(["Files", "Folders"]).get().execute_query()
        for file in parent_folder.files:
            if file.name.endswith(".xml"):
                file_prefix = file.name.split('/')[-1].split('-')[0]
                if file_prefix in ["Cartridge_PAT","Cartridge_WET"]:
                  file_dict[file.serverRelativeUrl] = file.unique_id
        for folder in parent_folder.folders:
            traverse_sharepoint_folder(folder, file_dict=file_dict)       

    file_dict = {}
    traverse_sharepoint_folder(sharepoint_folder, file_dict)
    return file_dict

# %%
# %%time
sharepoint_ids = get_sharepoint_ids(config["SAMPLE_DATA_FOLDER_1"], ctx)
len(sharepoint_ids)
# Out:
# CPU times: user 646 ms, sys: 16.5 ms, total: 662 ms
# Wall time: 2.43 s
# 400

# %%
dest_folder = "../../hae/From_SharePoint/"
metadata_filepath = os.path.join(dest_folder, "T1-20D-101854_20230204_140216_metadata.json")

# %%
for guid in sharepoint_ids.values():
    tegxml = TEGXMLProcessor.from_sharepoint_guid(ctx, guid)
    tegxml.parse()
    tegxml.pop_lists()

    with open(metadata_filepath, "a") as f:
        f.write(json.dumps(tegxml.d, indent=4))
# Out:
# 2023-04-27@11:22:28.825|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:22:29.110|INFO|from_sharepoint_guid|read 430,097 bytes from file 3082a42f-f450-455c-b9f8-00644b180c6e
# 2023-04-27@11:22:29.117|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:22:29.253|INFO|parse|XML parsed
# 2023-04-27@11:22:29.260|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:22:29.580|INFO|from_sharepoint_guid|read 1,197,273 bytes from file 88cbb53f-0fb0-4dc5-9ea6-0094b2b1a0bb
# 2023-04-27@11:22:29.584|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:22:29.943|INFO|parse|XML parsed
# 2023-04-27@11:22:29.951|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:22:30.301|INFO|from_sharepoint_guid|read 539,636 bytes from file 29380e25-bde5-40a6-8963-00d3b0a67116
# 2023-04-27@11:22:30.304|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11
INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:00.963|INFO|parse|XML parsed
# 2023-04-27@11:23:00.969|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:01.302|INFO|from_sharepoint_guid|read 457,210 bytes from file 9b9267b5-5707-4eea-9b45-1aedcdb50f94
# 2023-04-27@11:23:01.304|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:01.415|INFO|parse|XML parsed
# 2023-04-27@11:23:01.420|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:01.787|INFO|from_sharepoint_guid|read 1,493,711 bytes from file 73f7bf59-2561-40b8-b873-1bd63cc13bb3
# 2023-04-27@11:23:01.791|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:02.224|INFO|parse|XML parsed
# 2023-04-27@11:23:02.230|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:02.508|INFO|from_sharepoint_guid|read 449,111 bytes from file fdd83416-a6a2-4e49-8849-1c82cbfd2687
# 2023-04-27@11:23:02.510|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:02.647|INFO|parse|XML parsed
# 2023-04-27@11:23:02.653|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:02.996|INFO|from_sharepoint_guid|read 1,218,510 bytes from file 487ead91-d256-40f3-9381-1cafb657638b
# 2023-04-27@11:23:03.001|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:03.314|INFO|parse|XML parsed
# 2023-04-27@11:23:03.318|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:03.639|INFO|from_sharepoint_guid|read 1,218,438 bytes from file 61cdb344-5c13-4392-8f70-1de7d879bd3c
# 2023-04-27@11:23:03.643|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:03.961|INFO|parse|XML parsed
# 2023-04-27@11:23:03.968|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:04.297|INFO|from_sharepoint_guid|read 217,516 bytes from file 32369a8d-114d-4d0b-ae69-1fddd2621aa8
# 2023-04-27@11:23:04.299|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:04.356|INFO|parse|XML parsed
# 2023-04-27@11:23:04.366|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:04.668|INFO|from_sharepoint_guid|read 435,733 bytes from file d7b77ef7-6c1c-4803-a2cf-21992ad19014
# 2023-04-27@11:23:04.670|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:04.773|INFO|parse|XML parsed
# 2023-04-27@11:23:04.778|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:05.242|INFO|from_sharepoint_guid|read 1,270,190 bytes from file 5742abd0-4dba-460f-aae4-21c1b1454670
# 2023-04-27@11:23:05.247|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:05.617|INFO|parse|XML parsed
# 2023-04-27@11:23:05.625|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:07.191|INFO|from_sharepoint_guid|read 1,190,496 bytes from file 5b7170e7-2d58-43ef-b8b6-229d00bd5cac
# 2023-04-27@11:23:07.199|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:07.502|INFO|parse|XML parsed
# 2023-04-27@11:23:07.507|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:07.993|INFO|from_sharepoint_guid|read 484,271 bytes from file 1f1d9b74-f9e2-40aa-9623-24ef725b11e8
# 2023-04-27@11:23:07.998|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:08.116|INFO|parse|XML parsed
# 2023-04-27@11:23:08.122|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:08.489|INFO|from_sharepoint_guid|read 1,105,149 bytes from file 6c957de2-f33d-4b2a-9360-2607a17d0a49
# 2023-04-27@11:23:08.492|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:08.786|INFO|parse|XML parsed
# 2023-04-27@11:23:08.791|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:09.089|INFO|from_sharepoint_guid|read 1,230,951 bytes from file 0211ec54-cfc8-4129-b409-26f168b2da66
# 2023-04-27@11:23:09.091|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:09.450|INFO|parse|XML parsed
# 2023-04-27@11:23:09.457|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:09.755|INFO|from_sharepoint_guid|read 432,400 bytes from file 5380bcc8-b606-45a1-9ab2-26f9b46c9a78
# 2023-04-27@11:23:09.756|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:09.862|INFO|parse|XML parsed
# 2023-04-27@11:23:09.868|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:10.160|INFO|from_sharepoint_guid|read 1,126,435 bytes from file 2ef39a71-c898-4f07-8f9a-2738f73883e6
# 2023-04-27@11:23:10.166|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:10.444|INFO|parse|XML parsed
# 2023-04-27@11:23:10.449|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:10.782|INFO|from_sharepoint_guid|read 1,024,588 bytes from file 0975def6-61fa-4574-b8cb-273dbfd1d02f
# 2023-04-27@11:23:10.785|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:11.047|INFO|parse|XML parsed
# 2023-04-27@11:23:11.052|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:11.402|INFO|from_sharepoint_guid|read 1,375,383 bytes from file cb6417e0-8b0f-4925-8ee4-2879edde5152
# 2023-04-27@11:23:11.410|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:11.757|INFO|parse|XML parsed
# 2023-04-27@11:23:11.763|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:12.187|INFO|from_sharepoint_guid|read 1,201,927 bytes from file a5265eef-31a9-44af-8894-28c03e2e5cf5
# 2023-04-27@11:23:12.195|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:12.493|INFO|parse|XML parsed
# 2023-04-27@11:23:12.498|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:12.979|INFO|from_sharepoint_guid|read 529,538 bytes from file 3c7ca3e8-b887-420b-9456-28c4e9d62d4f
# 2023-04-27@11:23:12.985|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:13.160|INFO|parse|XML parsed
# 2023-04-27@11:23:13.164|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:13.548|INFO|from_sharepoint_guid|read 1,189,599 bytes from file a94a6243-81f3-4f61-aef3-28cd053fa51c
# 2023-04-27@11:23:13.552|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:13.848|INFO|parse|XML parsed
# 2023-04-27@11:23:13.853|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:14.279|INFO|from_sharepoint_guid|read 1,203,142 bytes from file 50c83b50-8e72-4b89-926e-29c14b35cf94
# 2023-04-27@11:23:14.283|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:14.584|INFO|parse|XML parsed
# 2023-04-27@11:23:14.588|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:14.921|INFO|from_sharepoint_guid|read 279,242 bytes from file e5aacd3c-549a-4329-9ebf-29dbed5be8fe
# 2023-04-27@11:23:14.923|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:14.996|INFO|parse|XML parsed
# 2023-04-27@11:23:15.001|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:15.352|INFO|from_sharepoint_guid|read 1,066,144 bytes from file 3eb21597-449f-417c-bc64-2b59841921ee
# 2023-04-27@11:23:15.354|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:15.622|INFO|parse|XML parsed
# 2023-04-27@11:23:15.631|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:16.151|INFO|from_sharepoint_guid|read 521,347 bytes from file 1bf5f7f6-dcb4-4406-a335-2b6a55d05ab1
# 2023-04-27@11:23:16.154|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:16.293|INFO|parse|XML parsed
# 2023-04-27@11:23:16.298|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:16.672|INFO|from_sharepoint_guid|read 1,094,303 bytes from file a09ae70b-0c94-4965-94b0-2c16e8c8772c
# 2023-04-27@11:23:16.675|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:17.006|INFO|parse|XML parsed
# 2023-04-27@11:23:17.016|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:17.330|INFO|from_sharepoint_guid|read 1,132,465 bytes from file 731e4b84-eb68-4195-bd96-2c82e29302e5
# 2023-04-27@11:23:17.334|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:17.617|INFO|parse|XML parsed
# 2023-04-27@11:23:17.629|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:18.017|INFO|from_sharepoint_guid|read 1,124,598 bytes from file fb2e519b-ac23-4103-95da-2eb93ed9742a
# 2023-04-27@11:23:18.026|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:18.301|INFO|parse|XML parsed
# 2023-04-27@11:23:18.306|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:18.699|INFO|from_sharepoint_guid|read 519,540 bytes from file 483726e9-ca12-4c69-9c0c-2f1904372f3a
# 2023-04-27@11:23:18.701|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:18.844|INFO|parse|XML parsed
# 2023-04-27@11:23:18.849|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:19.174|INFO|from_sharepoint_guid|read 1,131,903 bytes from file 97aaf3c4-6dea-40bd-91f1-2fa8a8487d08
# 2023-04-27@11:23:19.178|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:19.482|INFO|parse|XML parsed
# 2023-04-27@11:23:19.487|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:19.940|INFO|from_sharepoint_guid|read 519,795 bytes from file 14cebe4e-3436-4cdf-827f-31cfd3f75d5f
# 2023-04-27@11:23:19.943|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:20.091|INFO|parse|XML parsed
# 2023-04-27@11:23:20.100|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:20.479|INFO|from_sharepoint_guid|read 539,242 bytes from file 696b335d-0b8e-4a5e-984c-31f5a898c61c
# 2023-04-27@11:23:20.482|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:20.629|INFO|parse|XML parsed
# 2023-04-27@11:23:20.638|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:21.054|INFO|from_sharepoint_guid|read 1,138,458 bytes from file 0e42f32f-38ee-4e1d-bdd0-3261253b863e
# 2023-04-27@11:23:21.056|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:21.396|INFO|parse|XML parsed
# 2023-04-27@11:23:21.400|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:21.784|INFO|from_sharepoint_guid|read 1,167,825 bytes from file 6d3c62c1-4928-4d21-af43-33902c44e9ef
# 2023-04-27@11:23:21.787|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:22.089|INFO|parse|XML parsed
# 2023-04-27@11:23:22.094|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:22.414|INFO|from_sharepoint_guid|read 1,203,928 bytes from file dcc54875-2b2f-4474-8e54-339d2389c76d
# 2023-04-27@11:23:22.416|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:22.736|INFO|parse|XML parsed
# 2023-04-27@11:23:22.740|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:23.440|INFO|from_sharepoint_guid|read 1,153,097 bytes from file 631d64f1-4420-472d-8553-351b68e6bccc
# 2023-04-27@11:23:23.447|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:23.743|INFO|parse|XML parsed
# 2023-04-27@11:23:23.754|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:24.244|INFO|from_sharepoint_guid|read 1,091,942 bytes from file 686778a6-22fb-479c-aaf8-35303eb65b28
# 2023-04-27@11:23:24.246|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:24.633|INFO|parse|XML parsed
# 2023-04-27@11:23:24.639|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:25.011|INFO|from_sharepoint_guid|read 1,224,012 bytes from file 143dd821-4cdb-4dbb-aa4c-35ba3ead2d63
# 2023-04-27@11:23:25.014|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:25.392|INFO|parse|XML parsed
# 2023-04-27@11:23:25.399|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:25.808|INFO|from_sharepoint_guid|read 1,193,079 bytes from file 9c02628d-8bb7-42a2-8ef7-35e5e8597ad8
# 2023-04-27@11:23:25.811|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:26.156|INFO|parse|XML parsed
# 2023-04-27@11:23:26.161|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:26.574|INFO|from_sharepoint_guid|read 1,169,953 bytes from file 0a930ddf-6aad-4c4f-b33c-36437e24151b
# 2023-04-27@11:23:26.576|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:26.870|INFO|parse|XML parsed
# 2023-04-27@11:23:26.876|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:27.247|INFO|from_sharepoint_guid|read 1,083,639 bytes from file 38300b74-202e-4d6a-ab1b-375eff8a263e
# 2023-04-27@11:23:27.249|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:27.569|INFO|parse|XML parsed
# 2023-04-27@11:23:27.575|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:28.095|INFO|from_sharepoint_guid|read 553,196 bytes from file b0cd2de4-3d29-4d53-a130-378d7aa9a441
# 2023-04-27@11:23:28.100|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:28.246|INFO|parse|XML parsed
# 2023-04-27@11:23:28.253|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:28.645|INFO|from_sharepoint_guid|read 178,355 bytes from file 0d3a3b23-5bab-4d8d-b22e-386ec59abeed
# 2023-04-27@11:23:28.647|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:28.694|INFO|parse|XML parsed
# 2023-04-27@11:23:28.699|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:28.973|INFO|from_sharepoint_guid|read 723,037 bytes from file 7744a52e-729d-4ba1-b9d7-38f77ef13a18
# 2023-04-27@11:23:28.976|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:29.160|INFO|parse|XML parsed
# 2023-04-27@11:23:29.167|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:29.589|INFO|from_sharepoint_guid|read 1,080,065 bytes from file 32ad1789-26ec-4fc2-ac68-39487847c3fc
# 2023-04-27@11:23:29.592|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:29.900|INFO|parse|XML parsed
# 2023-04-27@11:23:29.926|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:30.335|INFO|from_sharepoint_guid|read 1,071,097 bytes from file 4e05cfb0-ebcf-4ebf-aeca-3a99f12ff751
# 2023-04-27@11:23:30.337|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:30.601|INFO|parse|XML parsed
# 2023-04-27@11:23:30.608|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:30.958|INFO|from_sharepoint_guid|read 1,141,986 bytes from file a05155db-2b6e-4f77-8200-3aa913e84b2a
# 2023-04-27@11:23:30.961|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:31.296|INFO|parse|XML parsed
# 2023-04-27@11:23:31.300|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:31.657|INFO|from_sharepoint_guid|read 1,847,320 bytes from file 99c9d433-a41a-4613-a502-3accb79e2513
# 2023-04-27@11:23:31.662|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:32.123|INFO|parse|XML parsed
# 2023-04-27@11:23:32.131|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:32.556|INFO|from_sharepoint_guid|read 1,165,177 bytes from file 4be90672-daef-4faa-9fd3-3b156a40ab1e
# 2023-04-27@11:23:32.565|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:32.847|INFO|parse|XML parsed
# 2023-04-27@11:23:32.855|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:33.151|INFO|from_sharepoint_guid|read 542,311 bytes from file 3ce50e8d-8a15-4101-86e8-3b2f2afeb5bc
# 2023-04-27@11:23:33.157|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:33.292|INFO|parse|XML parsed
# 2023-04-27@11:23:33.298|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:33.607|INFO|from_sharepoint_guid|read 1,239,595 bytes from file 04683831-ea9c-4c2f-9885-3b44cb127637
# 2023-04-27@11:23:33.610|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:33.915|INFO|parse|XML parsed
# 2023-04-27@11:23:33.923|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:34.289|INFO|from_sharepoint_guid|read 1,797,255 bytes from file b7920e3b-6902-465c-babb-3b7b5f92c6b9
# 2023-04-27@11:23:34.293|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:34.790|INFO|parse|XML parsed
# 2023-04-27@11:23:34.795|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:35.190|INFO|from_sharepoint_guid|read 1,126,918 bytes from file c36c5581-549e-4919-8427-3cb08a772beb
# 2023-04-27@11:23:35.201|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:35.483|INFO|parse|XML parsed
# 2023-04-27@11:23:35.488|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:35.841|INFO|from_sharepoint_guid|read 1,154,768 bytes from file 07c44ee6-f258-4e8b-93fa-3cc072576a0e
# 2023-04-27@11:23:35.844|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:36.138|INFO|parse|XML parsed
# 2023-04-27@11:23:36.144|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:36.495|INFO|from_sharepoint_guid|read 532,838 bytes from file 833be5a9-9302-4f60-a7c6-3f1a7d135bd4
# 2023-04-27@11:23:36.502|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:36.623|INFO|parse|XML parsed
# 2023-04-27@11:23:36.639|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23
INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:44.603|INFO|parse|XML parsed
# 2023-04-27@11:23:44.608|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:45.007|INFO|from_sharepoint_guid|read 1,205,136 bytes from file e235a8bd-028a-4c6e-abf5-46f2141967b0
# 2023-04-27@11:23:45.010|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:45.463|INFO|parse|XML parsed
# 2023-04-27@11:23:45.468|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:45.822|INFO|from_sharepoint_guid|read 1,179,878 bytes from file d3b6b3a6-e9b2-4b22-81a1-485c1e259618
# 2023-04-27@11:23:45.826|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:46.158|INFO|parse|XML parsed
# 2023-04-27@11:23:46.164|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:46.571|INFO|from_sharepoint_guid|read 1,496,035 bytes from file 0f103ff3-6ccf-4f5c-affc-49bb1b7e6f8d
# 2023-04-27@11:23:46.574|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:46.960|INFO|parse|XML parsed
# 2023-04-27@11:23:46.965|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:47.378|INFO|from_sharepoint_guid|read 1,115,519 bytes from file 2d7cfdf2-df9b-4e04-88b6-49ef5cd1e231
# 2023-04-27@11:23:47.388|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:47.716|INFO|parse|XML parsed
# 2023-04-27@11:23:47.721|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:48.100|INFO|from_sharepoint_guid|read 1,888,305 bytes from file 01e6dbeb-8023-4408-8b11-4bbef51f5fe1
# 2023-04-27@11:23:48.104|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:48.579|INFO|parse|XML parsed
# 2023-04-27@11:23:48.585|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:48.889|INFO|from_sharepoint_guid|read 221,512 bytes from file 03d9b834-2828-40ad-ab3b-4bc795fa89e2
# 2023-04-27@11:23:48.898|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:48.951|INFO|parse|XML parsed
# 2023-04-27@11:23:48.956|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:49.418|INFO|from_sharepoint_guid|read 1,063,882 bytes from file caba5386-f565-492e-9797-4bfa2b2a7f4a
# 2023-04-27@11:23:49.421|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:49.693|INFO|parse|XML parsed
# 2023-04-27@11:23:49.698|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:50.146|INFO|from_sharepoint_guid|read 1,267,597 bytes from file 3eb2af8b-a773-4d4c-9728-4c9fde644f0b
# 2023-04-27@11:23:50.149|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:50.459|INFO|parse|XML parsed
# 2023-04-27@11:23:50.466|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:50.836|INFO|from_sharepoint_guid|read 440,469 bytes from file a8ac6156-2ef0-450d-8988-4cfaebae4140
# 2023-04-27@11:23:50.837|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:51.003|INFO|parse|XML parsed
# 2023-04-27@11:23:51.007|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:51.310|INFO|from_sharepoint_guid|read 501,279 bytes from file abddc299-f346-4f40-8fe0-4d3fe95d2f61
# 2023-04-27@11:23:51.313|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:51.437|INFO|parse|XML parsed
# 2023-04-27@11:23:51.441|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:51.821|INFO|from_sharepoint_guid|read 1,311,711 bytes from file 78228004-6e16-429f-a252-4e5176e74a81
# 2023-04-27@11:23:51.825|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:52.148|INFO|parse|XML parsed
# 2023-04-27@11:23:52.153|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:52.603|INFO|from_sharepoint_guid|read 1,443,665 bytes from file e1d0956a-b4bf-47db-b756-4e743c7d9b50
# 2023-04-27@11:23:52.606|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:52.963|INFO|parse|XML parsed
# 2023-04-27@11:23:52.971|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:53.302|INFO|from_sharepoint_guid|read 506,967 bytes from file d4cbba37-0438-4aad-9833-5156bbed0b25
# 2023-04-27@11:23:53.304|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:53.434|INFO|parse|XML parsed
# 2023-04-27@11:23:53.439|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:53.803|INFO|from_sharepoint_guid|read 1,045,260 bytes from file e7c43225-03c9-45ac-90e7-522b4d9e27de
# 2023-04-27@11:23:53.806|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:54.121|INFO|parse|XML parsed
# 2023-04-27@11:23:54.126|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:54.432|INFO|from_sharepoint_guid|read 447,492 bytes from file aa468535-2d3e-4c16-ad73-52565849248f
# 2023-04-27@11:23:54.435|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:54.551|INFO|parse|XML parsed
# 2023-04-27@11:23:54.556|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:54.987|INFO|from_sharepoint_guid|read 1,169,583 bytes from file 84641d77-2adb-4406-bd16-52da70daf76e
# 2023-04-27@11:23:54.989|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:55.289|INFO|parse|XML parsed
# 2023-04-27@11:23:55.297|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:55.594|INFO|from_sharepoint_guid|read 558,256 bytes from file f99f9059-923b-41e9-8611-54dfff984fff
# 2023-04-27@11:23:55.596|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:55.738|INFO|parse|XML parsed
# 2023-04-27@11:23:55.745|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:56.151|INFO|from_sharepoint_guid|read 1,290,453 bytes from file 3da09acb-a02e-49b8-9e94-5651a5195c7b
# 2023-04-27@11:23:56.154|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:56.477|INFO|parse|XML parsed
# 2023-04-27@11:23:56.481|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:57.010|INFO|from_sharepoint_guid|read 1,721,156 bytes from file 72c82557-2700-44e4-b24f-5782263b2d7e
# 2023-04-27@11:23:57.013|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:57.502|INFO|parse|XML parsed
# 2023-04-27@11:23:57.509|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:57.807|INFO|from_sharepoint_guid|read 421,543 bytes from file 327ece69-aaa3-4ee7-b80a-58bafd84a403
# 2023-04-27@11:23:57.814|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:57.922|INFO|parse|XML parsed
# 2023-04-27@11:23:57.928|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:58.267|INFO|from_sharepoint_guid|read 1,157,985 bytes from file e5951d76-1678-4e3e-a9d0-58ee8893cd62
# 2023-04-27@11:23:58.271|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:58.606|INFO|parse|XML parsed
# 2023-04-27@11:23:58.611|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:58.912|INFO|from_sharepoint_guid|read 424,026 bytes from file f12e94aa-b40c-4146-af27-59100004d826
# 2023-04-27@11:23:58.914|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:59.018|INFO|parse|XML parsed
# 2023-04-27@11:23:59.026|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:23:59.385|INFO|from_sharepoint_guid|read 1,216,439 bytes from file 0d84bbb1-3221-4079-8ece-5c40c905d4c2
# 2023-04-27@11:23:59.390|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:23:59.721|INFO|parse|XML parsed
# 2023-04-27@11:23:59.725|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:00.341|INFO|from_sharepoint_guid|read 1,106,751 bytes from file a79bfade-56d9-44d2-8979-5c8de8542cd4
# 2023-04-27@11:24:00.344|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:00.619|INFO|parse|XML parsed
# 2023-04-27@11:24:00.631|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:00.959|INFO|from_sharepoint_guid|read 561,878 bytes from file 124a5729-ae0e-462c-b317-5cdbf40d883a
# 2023-04-27@11:24:00.962|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:01.106|INFO|parse|XML parsed
# 2023-04-27@11:24:01.114|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:01.518|INFO|from_sharepoint_guid|read 503,310 bytes from file 19ebb85e-d078-4ce2-b98f-5d69060d1c0a
# 2023-04-27@11:24:01.520|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:01.650|INFO|parse|XML parsed
# 2023-04-27@11:24:01.665|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:01.957|INFO|from_sharepoint_guid|read 466,286 bytes from file 963856c2-5e77-405b-9ffd-5d8541fa40a9
# 2023-04-27@11:24:01.959|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:02.114|INFO|parse|XML parsed
# 2023-04-27@11:24:02.119|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:02.430|INFO|from_sharepoint_guid|read 541,593 bytes from file f8e477a1-c67b-4f2e-9f50-5d881f0f5792
# 2023-04-27@11:24:02.431|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:02.565|INFO|parse|XML parsed
# 2023-04-27@11:24:02.570|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:02.977|INFO|from_sharepoint_guid|read 262,086 bytes from file 3fc443b2-6756-4b1b-ac4f-5dc0911b7803
# 2023-04-27@11:24:02.978|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:03.049|INFO|parse|XML parsed
# 2023-04-27@11:24:03.053|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:03.460|INFO|from_sharepoint_guid|read 611,814 bytes from file 5d800819-7b53-4ad5-956e-5dcb805baed9
# 2023-04-27@11:24:03.462|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:03.615|INFO|parse|XML parsed
# 2023-04-27@11:24:03.621|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:24:03.918|INFO|from_sharepoint_guid|read 549,819 bytes from file 0840198e-d7f4-4286-aef7-5efed497c626
# 2023-04-27@11:24:03.921|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:24:04.061|INFO|parse|XML parsed
# 2023-04-27@11:24:04.065|DEBUG|from_sharepoint_guid|reading from SharePoint...
# ...
# 2023-04-27@11:26:07.023|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:07.354|INFO|parse|XML parsed
# 2023-04-27@11:26:07.361|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:07.712|INFO|from_sharepoint_guid|read 309,608 bytes from file 0d2af7c8-c720-45b3-88e0-e1404eade429
# 2023-04-27@11:26:07.718|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:07.802|INFO|parse|XML parsed
# 2023-04-27@11:26:07.807|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:08.204|INFO|from_sharepoint_guid|read 1,186,813 bytes from file 22d8a17e-63e7-470d-9ffb-e18ac73ceed5
# 2023-04-27@11:26:08.207|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:08.504|INFO|parse|XML parsed
# 2023-04-27@11:26:08.509|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:08.776|INFO|from_sharepoint_guid|read 448,319 bytes from file 0b29abfc-0638-4e6d-8940-e1cf17663e84
# 2023-04-27@11:26:08.778|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:08.896|INFO|parse|XML parsed
# 2023-04-27@11:26:08.901|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:09.440|INFO|from_sharepoint_guid|read 1,165,506 bytes from file 6db8d49d-c412-4bd4-94f2-e35c5097a4c6
# 2023-04-27@11:26:09.444|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:09.738|INFO|parse|XML parsed
# 2023-04-27@11:26:09.747|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:10.085|INFO|from_sharepoint_guid|read 517,681 bytes from file 3336ec4e-a521-4e39-97ae-e3bcc5524f40
# 2023-04-27@11:26:10.090|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:10.228|INFO|parse|XML parsed
# 2023-04-27@11:26:10.234|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:10.542|INFO|from_sharepoint_guid|read 493,790 bytes from file 354edca4-6926-48a3-9e69-e5814747cd85
# 2023-04-27@11:26:10.544|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:10.670|INFO|parse|XML parsed
# 2023-04-27@11:26:10.675|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:11.164|INFO|from_sharepoint_guid|read 878,553 bytes from file 1012d1f5-2c0a-48ff-b730-e5c0d7bd5bff
# 2023-04-27@11:26:11.166|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:11.381|INFO|parse|XML parsed
# 2023-04-27@11:26:11.386|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:11.829|INFO|from_sharepoint_guid|read 1,149,919 bytes from file fa1ec5ef-156e-405c-a680-e60ebe6ce1ec
# 2023-04-27@11:26:11.831|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:12.179|INFO|parse|XML parsed
# 2023-04-27@11:26:12.186|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:12.682|INFO|from_sharepoint_guid|read 1,114,001 bytes from file 44472cb0-2009-41de-a603-e648dd62ceef
# 2023-04-27@11:26:12.684|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:12.964|INFO|parse|XML parsed
# 2023-04-27@11:26:12.970|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:13.423|INFO|from_sharepoint_guid|read 1,297,170 bytes from file 40fbc4a7-3265-49b8-b9bc-e6981ef3196a
# 2023-04-27@11:26:13.430|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:13.760|INFO|parse|XML parsed
# 2023-04-27@11:26:13.766|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:14.127|INFO|from_sharepoint_guid|read 342,574 bytes from file b83171fc-ace5-4770-91d2-e6aae3b17398
# 2023-04-27@11:26:14.129|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:14.220|INFO|parse|XML parsed
# 2023-04-27@11:26:14.226|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:14.622|INFO|from_sharepoint_guid|read 1,110,886 bytes from file 9b735ecd-befa-40ac-a31f-e7473202f8a1
# 2023-04-27@11:26:14.625|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:14.968|INFO|parse|XML parsed
# 2023-04-27@11:26:14.976|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:15.382|INFO|from_sharepoint_guid|read 1,189,157 bytes from file 60d593d5-b6d2-49fc-8d42-e7e916cf58d2
# 2023-04-27@11:26:15.387|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:15.746|INFO|parse|XML parsed
# 2023-04-27@11:26:15.750|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:16.038|INFO|from_sharepoint_guid|read 406,683 bytes from file c5381cb1-c3e0-45c7-a98a-e83d08703dac
# 2023-04-27@11:26:16.040|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:16.144|INFO|parse|XML parsed
# 2023-04-27@11:26:16.149|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:16.559|INFO|from_sharepoint_guid|read 1,149,195 bytes from file 743a567b-597b-4f45-9b46-e96b05dc9b14
# 2023-04-27@11:26:16.563|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:16.849|INFO|parse|XML parsed
# 2023-04-27@11:26:16.857|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:17.159|INFO|from_sharepoint_guid|read 613,880 bytes from file 90cb7e7d-16cf-481b-b4fd-e99a302cc129
# 2023-04-27@11:26:17.161|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:17.325|INFO|parse|XML parsed
# 2023-04-27@11:26:17.330|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:17.644|INFO|from_sharepoint_guid|read 435,091 bytes from file 9a8b2b6e-02fa-4747-b502-ea3b547a3ddf
# 2023-04-27@11:26:17.645|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:17.760|INFO|parse|XML parsed
# 2023-04-27@11:26:17.765|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:18.083|INFO|from_sharepoint_guid|read 544,220 bytes from file 37e8caf6-5613-4f23-96ec-ec8d9d296a48
# 2023-04-27@11:26:18.085|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:18.217|INFO|parse|XML parsed
# 2023-04-27@11:26:18.222|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:18.774|INFO|from_sharepoint_guid|read 1,184,481 bytes from file 8b1aa884-3da8-40c1-9795-ed61e17cf199
# 2023-04-27@11:26:18.778|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:19.130|INFO|parse|XML parsed
# 2023-04-27@11:26:19.136|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:19.401|INFO|from_sharepoint_guid|read 261,620 bytes from file 50fda164-1335-44b6-b42d-ee9c33764351
# 2023-04-27@11:26:19.406|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:19.467|INFO|parse|XML parsed
# 2023-04-27@11:26:19.474|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:19.755|INFO|from_sharepoint_guid|read 139,722 bytes from file 221dcfc3-78f0-450b-8e88-ef3819f6917c
# 2023-04-27@11:26:19.756|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:19.790|INFO|parse|XML parsed
# 2023-04-27@11:26:19.797|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:20.193|INFO|from_sharepoint_guid|read 1,128,279 bytes from file 616553da-9c8d-4324-836f-effd8acfe424
# 2023-04-27@11:26:20.196|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:20.473|INFO|parse|XML parsed
# 2023-04-27@11:26:20.479|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:20.792|INFO|from_sharepoint_guid|read 522,598 bytes from file f7b81fea-fbdf-4155-a89c-f05968cbdab7
# 2023-04-27@11:26:20.795|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:20.923|INFO|parse|XML parsed
# 2023-04-27@11:26:20.928|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:21.261|INFO|from_sharepoint_guid|read 1,242,894 bytes from file 73ceb870-8a62-4c4a-9491-f0d34d575e83
# 2023-04-27@11:26:21.264|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:21.566|INFO|parse|XML parsed
# 2023-04-27@11:26:21.574|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:21.996|INFO|from_sharepoint_guid|read 1,186,586 bytes from file 27c1c2a4-7866-400a-a9bf-f0d57dfc0deb
# 2023-04-27@11:26:21.999|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:22.295|INFO|parse|XML parsed
# 2023-04-27@11:26:22.304|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:22.592|INFO|from_sharepoint_guid|read 273,943 bytes from file 75a216ea-c931-4a50-970f-f103be3fb839
# 2023-04-27@11:26:22.593|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:22.664|INFO|parse|XML parsed
# 2023-04-27@11:26:22.671|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:23.226|INFO|from_sharepoint_guid|read 1,242,621 bytes from file 518d1865-9f23-4d9d-b116-f157435354ae
# 2023-04-27@11:26:23.228|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:23.591|INFO|parse|XML parsed
# 2023-04-27@11:26:23.597|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:23.965|INFO|from_sharepoint_guid|read 1,208,736 bytes from file 49f33e22-7ae8-46ef-8fa3-f180ec0106f2
# 2023-04-27@11:26:23.971|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:24.287|INFO|parse|XML parsed
# 2023-04-27@11:26:24.293|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:24.644|INFO|from_sharepoint_guid|read 879,245 bytes from file 5e4b6e6f-ad05-45bd-9d3a-f1a33a0bea94
# 2023-04-27@11:26:24.651|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:24.870|INFO|parse|XML parsed
# 2023-04-27@11:26:24.875|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:25.160|INFO|from_sharepoint_guid|read 179,505 bytes from file 20c51b1b-5455-45ae-aaba-f1c641b3f001
# 2023-04-27@11:26:25.161|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:25.207|INFO|parse|XML parsed
# 2023-04-27@11:26:25.213|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:25.574|INFO|from_sharepoint_guid|read 535,287 bytes from file 8eecbfdc-1501-46cc-b4ad-f24ba2e72ba6
# 2023-04-27@11:26:25.577|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:25.710|INFO|parse|XML parsed
# 2023-04-27@11:26:25.717|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:26.048|INFO|from_sharepoint_guid|read 514,503 bytes from file c61cb79a-5a59-427b-aa83-f2b12ab5e5d9
# 2023-04-27@11:26:26.050|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:26.186|INFO|parse|XML parsed
# 2023-04-27@11:26:26.191|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:26.560|INFO|from_sharepoint_guid|read 1,174,852 bytes from file a1905a85-3364-40e0-89ae-f2ea2cb7f566
# 2023-04-27@11:26:26.563|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:26.880|INFO|parse|XML parsed
# 2023-04-27@11:26:26.887|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:27.308|INFO|from_sharepoint_guid|read 1,122,139 bytes from file 437fb7ed-2b16-48bd-a5e9-f2efd274fff8
# 2023-04-27@11:26:27.311|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:27.595|INFO|parse|XML parsed
# 2023-04-27@11:26:27.601|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:27.928|INFO|from_sharepoint_guid|read 1,038,959 bytes from file b555ad39-79ae-4fe3-9240-f4f11c4b039c
# 2023-04-27@11:26:27.931|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:28.246|INFO|parse|XML parsed
# 2023-04-27@11:26:28.252|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:28.757|INFO|from_sharepoint_guid|read 1,217,120 bytes from file 3c3129db-1159-4827-bb8b-f57a7581e4c1
# 2023-04-27@11:26:28.762|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:29.059|INFO|parse|XML parsed
# 2023-04-27@11:26:29.065|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:29.447|INFO|from_sharepoint_guid|read 444,380 bytes from file 8783fc61-cd27-490c-ae8d-f5b539600c9a
# 2023-04-27@11:26:29.450|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:29.564|INFO|parse|XML parsed
# 2023-04-27@11:26:29.570|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:29.849|INFO|from_sharepoint_guid|read 475,770 bytes from file f453783a-dc14-4c5c-942f-f5e5282a16b4
# 2023-04-27@11:26:29.850|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:29.972|INFO|parse|XML parsed
# 2023-04-27@11:26:29.977|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:30.422|INFO|from_sharepoint_guid|read 1,115,676 bytes from file 1e59acc3-eaa0-456c-80ff-f5f90c83f860
# 2023-04-27@11:26:30.424|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:30.705|INFO|parse|XML parsed
# 2023-04-27@11:26:30.710|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:31.597|INFO|from_sharepoint_guid|read 1,170,204 bytes from file 58aed681-f63c-443d-937d-f6bdae3a40bc
# 2023-04-27@11:26:31.605|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:31.951|INFO|parse|XML parsed
# 2023-04-27@11:26:31.956|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:32.695|INFO|from_sharepoint_guid|read 475,124 bytes from file 97818f31-46a1-4495-a0d1-f6bdf886cfa7
# 2023-04-27@11:26:32.697|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:32.820|INFO|parse|XML parsed
# 2023-04-27@11:26:32.827|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:33.692|INFO|from_sharepoint_guid|read 1,238,139 bytes from file a9eb61f1-786c-41f1-b148-f72531449b19
# 2023-04-27@11:26:33.695|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:34.011|INFO|parse|XML parsed
# 2023-04-27@11:26:34.015|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:34.708|INFO|from_sharepoint_guid|read 37,429 bytes from file 834e7255-c66e-4b91-b91e-f889bd1fc7d2
# 2023-04-27@11:26:34.710|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:34.716|INFO|parse|XML parsed
# 2023-04-27@11:26:34.723|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:35.454|INFO|from_sharepoint_guid|read 1,083,636 bytes from file 0ca3e303-75af-4be4-b5fe-f8e2bfe4cb8e
# 2023-04-27@11:26:35.456|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:35.742|INFO|parse|XML parsed
# 2023-04-27@11:26:35.747|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:36.521|INFO|from_sharepoint_guid|read 1,227,777 bytes from file 17cdf91e-c0a5-4baa-8b93-f96aceb61ea9
# 2023-04-27@11:26:36.525|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:36.863|INFO|parse|XML parsed
# 2023-04-27@11:26:36.868|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:37.151|INFO|from_sharepoint_guid|read 396,572 bytes from file e3cef936-a7de-4042-a136-fa4352689f87
# 2023-04-27@11:26:37.152|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:37.254|INFO|parse|XML parsed
# 2023-04-27@11:26:37.262|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:37.550|INFO|from_sharepoint_guid|read 148,346 bytes from file ed31259e-4de3-4fed-ab77-fca972541bbd
# 2023-04-27@11:26:37.551|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:37.642|INFO|parse|XML parsed
# 2023-04-27@11:26:37.647|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:37.990|INFO|from_sharepoint_guid|read 486,998 bytes from file e92d57ac-96c9-4663-8e95-fcdfeb52557d
# 2023-04-27@11:26:37.992|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:38.107|INFO|parse|XML parsed
# 2023-04-27@11:26:38.113|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:38.446|INFO|from_sharepoint_guid|read 1,107,012 bytes from file 2603db31-4bea-4ac5-824d-fd2798203233
# 2023-04-27@11:26:38.449|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:38.736|INFO|parse|XML parsed
# 2023-04-27@11:26:38.740|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:39.097|INFO|from_sharepoint_guid|read 485,459 bytes from file be185818-894f-4e82-9ae7-fdb1ec019e69
# 2023-04-27@11:26:39.098|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:39.219|INFO|parse|XML parsed
# 2023-04-27@11:26:39.227|DEBUG|from_sharepoint_guid|reading from SharePoint...
# 2023-04-27@11:26:39.669|INFO|from_sharepoint_guid|read 1,430,483 bytes from file 8ee05c6b-5ee0-4099-83be-ff76e97ba961
# 2023-04-27@11:26:39.675|INFO|find_xml_offsets|found 2 XML fragment(s)
# 2023-04-27@11:26:40.037|INFO|parse|XML parsed

# %%
# # for local folders:
# base_folder = "../../hae/T1-19B-Cartridges/"
# xml_files = [f for f in os.listdir(base_folder) if f.endswith(".xml")]

# for file in xml_files:
#     xml_file = os.path.join(base_folder, file)
#     tegxml = TEGXMLProcessor(xml_file)
#     tegxml.parse()
#     tegxml.pop_lists()
#     tegxml.save_jsons()

# %% [markdown]
# ## Insights

# %%
import duckdb
import pandas as pd

# %%
pd.options.display.max_rows = 96
pd.options.display.max_colwidth = 256

# %%
con = duckdb.connect()

# %%
q = f"""
SELECT COUNT(DISTINCT Cartridge.CartridgeResult.TestResultID) AS run_count
FROM read_json_auto('{metadata_filepath}') metadata
"""
con.execute(q).df()
# Out:
#    run_count
# 0        400

# %%
q = f"""
SELECT
  Cartridge.CartridgeResult.InstrumentDetails.SerialNumber AS instrument_sn
  ,Cartridge.CartridgeResult.InstrumentDetails.InstrumentLocation AS instrument_location
  ,Cartridge.ManufacturingData.PrintedCartridgeLot AS printed_cartridge_lot
  ,Cartridge.CartridgeResult.ErrorReason AS error_reason
  ,COUNT(*) AS run_count
FROM read_json_auto('{metadata_filepath}') metadata
GROUP BY 1,2,3,4
ORDER BY 1,2,3
"""
df = con.execute(q).df()
df
# Out:
#     instrument_sn instrument_location printed_cartridge_lot  \
# 0   T1-20D-101854            TML 2031              010622-1
# 1   T1-20D-101854            TML 2031              010622-1
# 2   T1-20D-101854            TML 2031              010622-1
# 3   T1-20D-101854            TML 2031              011222-1
# 4   T1-20D-101854            TML 2031              021722-1
# 5   T1-20D-101854            TML 2031              030322-4
# 6   T1-20D-101854            TML 2031              030322-4
# 7   T1-20D-101854            TML 2031              030322-4
# 8   T1-20D-101854            TML 2031              030522-1
# 9   T1-20D-101854            TML 2031              030522-1
# 10  T1-20D-101854            TML 2031              031822-2
# 11  T1-20D-101854            TML 2031              042021-1
# 12  T1-20D-101854            TML 2031              050422-6
# 13  T1-20D-101854            TML 2031              050422-6
# 14  T1-20D-101854            TML 2031              050422-6
# 15  T1-20D-101854            TML 2031              062222-9
# 16  T1-20D-101854            TML 2031              062222-9
# 17  T1-20D-101854            TML 2031              062222-9
# 18  T1-20D-101854            TML 2031              062522-5
# 19  T1-20D-101854            TML 2031              062922-5
# 20  T1-20D-101854            TML 2031              062922-5
# 21  T1-20D-101854            TML 2031              070822-5
# 22  T1-20D-101854            TML 2031              070822-5
# 23  T1-20D-101854            TML 2031              071421-1
# 24  T1-20D-101854            TML 2031              071422-7
# 25  T1-20D-101854            TML 2031              071422-7
# 26  T1-20D-101854            TML 2031              071422-7
# 27  T1-20D-101854            TML 2031              071822-5
# 28  T1-20D-101854            TML 2031              071822-5
# 29  T1-20D-101854            TML 2031              072122-5
# 30  T1-20D-101854            TML 2031              072821-3
# 31  T1-20D-101854            TML 2031              080521-1
# 32  T1-20D-101854            TML 2031              080521-2
# 33  T1-20D-101854            TML 2031              083021-2
# 34  T1-20D-101854            TML 2031              092421-1
# 35  T1-20D-101854            TML 2031              100521-1
# 36  T1-20D-101854            TML 2031              101022-8
# 37  T1-20D-101854            TML 2031              102222-6
# 38  T1-20D-101854            TML 2031              102722-1
# 39  T1-20D-101854            TML 2031              102722-1
# 40  T1-20D-101854            TML 2031              102722-6
# 41  T1-20D-101854            TML 2031              102722-6
# 42  T1-20D-101854            TML 2031              102722-6
# 43  T1-20D-101854            TML 2031              110122-6
# 44  T1-20D-101854            TML 2031              110122-6
# 45  T1-20D-101854            TML 2031              110122-6
# 46  T1-20D-101854            TML 2031              111221-1
# 47  T1-20D-101854            TML 2031              111221-1
# 48  T1-20D-101854            TML 2031              111722-1
# 49  T1-20D-101854            TML 2031              111722-1
# 50  T1-20D-101854            TML 2031              111722-1
# 51  T1-20D-101854            TML 2031              112922-6
# 52  T1-20D-101854            TML 2031              112922-6
# 53  T1-20D-101854            TML 2031              112922-6
# 54  T1-20D-101854            TML 2031              112922-6
# 55  T1-20D-101854            TML 2031              121721-1
# 56  T1-20D-101854            TML 2031              121721-1
# 57  T1-20D-101854            TML 2031              121721-2
# 58  T1-20D-101854            TML 2031              121721-2
# 59  T1-20D-101854            TML 2031              121721-2
# 60  T1-20D-101854            TML 2031              121721-2
#
#                          error_reason  run_count
# 0                                None         16
# 1                             Aborted          8
# 2   ErrorDetectedInCartridgeOrChannel          1
# 3                                None         13
# 4                                None          2
# 5                                None         10
# 6                             Aborted         11
# 7   ErrorDetectedInCartridgeOrChannel          1
# 8                             Aborted          6
# 9                                None         14
# 10                               None          7
# 11                               None          2
# 12                               None         12
# 13  ErrorDetectedInCartridgeOrChannel          5
# 14                            Aborted          4
# 15  ErrorDetectedInCartridgeOrChannel          1
# 16                               None         17
# 17                            Aborted          6
# 18                               None         18
# 19                               None          9
# 20  ErrorDetectedInCartridgeOrChannel          2
# 21                               None          9
# 22                            Aborted          1
# 23                               None          2
# 24                               None          8
# 25                            Aborted          9
# 26                           TimedOut          1
# 27                               None          7
# 28                            Aborted          8
# 29                               None         10
# 30                            Aborted          1
# 31                               None          8
# 32                               None          6
# 33                               None         19
# 34                               None          8
# 35                               None          8
# 36                            Aborted          1
# 37                            Aborted          3
# 38                            Aborted          4
# 39                               None          3
# 40  ErrorDetectedInCartridgeOrChannel          2
# 41                            Aborted          9
# 42                               None         17
# 43                            Aborted          3
# 44                               None          3
# 45  ErrorDetectedInCartridgeOrChannel          1
# 46                               None         11
# 47                            Aborted          1
# 48                            Aborted          1
# 49  ErrorDetectedInCartridgeOrChannel          1
# 50                               None         25
# 51                               None         33
# 52  ErrorDetectedInCartridgeOrChannel          2
# 53                            Aborted          2
# 54                           TimedOut          2
# 55                               None         15
# 56                            Aborted          2
# 57                           TimedOut          4
# 58                               None         37
# 59  ErrorDetectedInCartridgeOrChannel          6
# 60                            Aborted         11

# %%
pd.crosstab(df.printed_cartridge_lot, df.error_reason)
# Out:
# error_reason           Aborted  ErrorDetectedInCartridgeOrChannel  None  \
# printed_cartridge_lot
# 010622-1                     1                                  1     1
# 011222-1                     0                                  0     1
# 021722-1                     0                                  0     1
# 030322-4                     1                                  1     1
# 030522-1                     1                                  0     1
# 031822-2                     0                                  0     1
# 042021-1                     0                                  0     1
# 050422-6                     1                                  1     1
# 062222-9                     1                                  1     1
# 062522-5                     0                                  0     1
# 062922-5                     0                                  1     1
# 070822-5                     1                                  0     1
# 071421-1                     0                                  0     1
# 071422-7                     1                                  0     1
# 071822-5                     1                                  0     1
# 072122-5                     0                                  0     1
# 072821-3                     1                                  0     0
# 080521-1                     0                                  0     1
# 080521-2                     0                                  0     1
# 083021-2                     0                                  0     1
# 092421-1                     0                                  0     1
# 100521-1                     0                                  0     1
# 101022-8                     1                                  0     0
# 102222-6                     1                                  0     0
# 102722-1                     1                                  0     1
# 102722-6                     1                                  1     1
# 110122-6                     1                                  1     1
# 111221-1                     1                                  0     1
# 111722-1                     1                                  1     1
# 112922-6                     1                                  1     1
# 121721-1                     1                                  0     1
# 121721-2                     1                                  1     1
#
# error_reason           TimedOut
# printed_cartridge_lot
# 010622-1                      0
# 011222-1                      0
# 021722-1                      0
# 030322-4                      0
# 030522-1                      0
# 031822-2                      0
# 042021-1                      0
# 050422-6                      0
# 062222-9                      0
# 062522-5                      0
# 062922-5                      0
# 070822-5                      0
# 071421-1                      0
# 071422-7                      1
# 071822-5                      0
# 072122-5                      0
# 072821-3                      0
# 080521-1                      0
# 080521-2                      0
# 083021-2                      0
# 092421-1                      0
# 100521-1                      0
# 101022-8                      0
# 102222-6                      0
# 102722-1                      0
# 102722-6                      0
# 110122-6                      0
# 111221-1                      0
# 111722-1                      0
# 112922-6                      1
# 121721-1                      0
# 121721-2                      1

# %% [markdown]
# ## Sandbox

# %%
# some other data elements of interest
# f"""
#   --,Cartridge.CartridgeResult.InstrumentDetails.InstrumentName AS instrument_name
#   --,Cartridge.TestType AS test_type
#   --,Cartridge.CartridgeResult.UserName AS user
#   --,YEAR(STRPTIME(Cartridge.CartridgeResult.InstrumentDetails.StartTime,'%Y-%m-%dT%H:%M:%S')) AS year
# """

# %%
#| hide
import nbdev; nbdev.nbdev_export()
